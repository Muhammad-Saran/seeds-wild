# %%
import pandas as pd

# %%
file_path = 'cleaned_data3.csv'

# %%
df = pd.read_csv(file_path)
# Out:
# C:\Users\FAWAD\AppData\Local\Temp\ipykernel_2128\2618208116.py:1: DtypeWarning: Columns (16,17,18,19,20,21,23) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file_path)

# %%
df.head(100)
# Out:
#     Seed_ID                 Seed_Name  \
# 0         1      Abutilon abutiloides
# 1         2       Abutilon americanum
# 2         3        Abutilon Jacquinii
# 3         4         Abutilon Lignosum
# 4         5      Abietinella abietina
# ..      ...                       ...
# 95       96        Abildgaardia ovata
# 96       97  Abildgaardia Monostachya
# 97       98      Cyperus Monostachyos
# 98       99  Fimbristylis monostachya
# 99      100        Fimbristylis ovata
#
#                                  Soil_Types        Plant_Category  \
# 0                         ["Loamy","Sandy"]       Flowering plant
# 1                         ["Loamy","Sandy"]  Herbaceous Perennial
# 2                         ["Loamy","Sandy"]                 Shrub
# 3                         ["Loamy","Sandy"]                 Shrub
# 4    ["Sandy loam","Clay loam","Peat moss"]                  Moss
# ..                                      ...                   ...
# ...
