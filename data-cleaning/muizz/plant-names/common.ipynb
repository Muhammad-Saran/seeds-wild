# %%
import pandas as pd

# %%
df = pd.read_csv('data_2.csv')

# %%
df.head()
# Out:
#    Seed_ID               Seed_Name                         Soil_Types  \
# 0  67300.0          Monarde citron  ["Loam","Sandy loam","Clay loam"]
# 1  67301.0            Montana Jack  ["Loam","Sandy Loam","Clay Loam"]
# 2  67302.0            Moravsky Div              ["Loam","Sandy Loam"]
# 3  67303.0            Morden Early            ["Loam","Clay","Sandy"]
# 4  67304.0  Mortgage Lifter Tomato  ["Loam","Sandy Loam","Clay Loam"]
#
#          Plant_Category                        Season  Watering  \
# 0  Herbaceous perennial           ["Summer","Spring"]      48.0
# 1       Flowering Plant           ["Spring","Summer"]      48.0
# 2                Flower           ["Summer","Autumn"]      24.0
# 3       Flowering Plant           ["Spring","Summer"]      24.0
# 4                Tomato  ["Spring","Summer","Autumn"]      24.0
#
#                                   Fertilization_List Fertilization_Time  \
# 0    ["Organic compost","Liquid seaweed fertilizer"]                  4
# ...

# %%
dff = df['Seed_Name']

# %%
dff.head()
# Out:
# 0            Monarde citron
# 1              Montana Jack
# 2              Moravsky Div
# 3              Morden Early
# 4    Mortgage Lifter Tomato
# Name: Seed_Name, dtype: object

# %%
dff.to_csv('plant-names1.csv', index=False)
