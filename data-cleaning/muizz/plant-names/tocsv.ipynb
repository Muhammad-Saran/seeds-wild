# %%
import pandas as pd

# %%
file_path = "plant-data.xlsx"
df = pd.read_excel(file_path)

# %%
output_csv_path = "plant-data.csv"
df.to_csv(output_csv_path, index=False)

# %%
df = pd.read_csv('plant-data.csv')

# %%
df = df.drop(columns='Seed_ID')

# %%
df.head()
# Out:
#               Seed_Name                              Soil_Types  \
# 0  abutilon abutiloides                       ["Loamy","Sandy"]
# 1   abutilon americanum                       ["Loamy","Sandy"]
# 2    abutilon jacquinii                       ["Loamy","Sandy"]
# 3     abutilon lignosum                       ["Loamy","Sandy"]
# 4  abietinella abietina  ["Sandy loam","Clay loam","Peat moss"]
#
#          Plant_Category                     Season              Watering  \
# 0       Flowering plant  ["Summer","Rainy season"]                    48
# 1  Herbaceous Perennial        ["Spring","Summer"]                03-Feb
# 2                 Shrub   ["Late spring","Summer"]                03-Feb
# 3                 Shrub                 ["Summer"]  12-24 hours interval
# 4                  Moss        ["Spring","Summer"]                    48
#
#                               Fertilization_List  Fertilization_Time  \
# ...
